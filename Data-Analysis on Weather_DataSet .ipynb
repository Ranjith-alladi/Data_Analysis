# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Weather Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %%
# Q. 1) Find all the unique 'Wind Speed' values in the data. 
unique_WindSpeed_values = df['Wind Speed_km/h'].unique()
print(unique_WindSpeed_values)
# Out:
# [ 9 24 26 15  4  0 19 17 11 22 35 13 20  6  7 30 32 41 39 28 44 33 37 52
#  46  2 50 48 57 63 43 83 70 54]

# %%
# Q. 2) Find the number of times when the 'Weather is exactly Clear'. 
ExactlyClear= df.value_counts(df.Weather=='Clear')
print(ExactlyClear)
# Out:
# Weather
# False    7458
# True     1326
# dtype: int64

# %%
# Q. 2) Find the number of times when the 'Weather is exactly Clear'.
clear_weather_count = df['Weather'].value_counts().get('Clear', 0)
print(clear_weather_count)
# Out:
# 1326

# %%
clear_weather_count = 0
for i in df.Weather:
    if i =='Clear':
        clear_weather_count+=1
print(clear_weather_count)
# Out:
# 1326

# %%
# Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'. 
WindSpeed_is_4 =df.value_counts(df['Wind Speed_km/h'] == 4)
print(WindSpeed_is_4)
# Out:
# Wind Speed_km/h
# False    8310
# True      474
# dtype: int64

# %%
wind_speed_count = df['Wind Speed_km/h'].value_counts().get(4, 0)
print(wind_speed_count)
# Out:
# 474

# %%
wind_speed_count  = 0
for i in df['Wind Speed_km/h']:
    if i == 4:
        wind_speed_count+=1
print(wind_speed_count)
# Out:
# 474

# %%
# Q. 4) Find out all the Null Values in the data. 
Weather_isnull = df.isnull().sum()
print(Weather_isnull)
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
# Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.
df.rename(columns = {'Weather':'Weather Condition'},inplace = True)

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %%
# Q. 6) What is the mean 'Visibility' ? 
mean_Visibility = df.Visibility_km.mean()
mean_Visibility
# Out:
# 27.664446721311162

# %%
# Q. 7) What is the Standard Deviation of 'Pressure' in this data? 
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# Q. 7) What is the Standard Deviation of 'Pressure' in this data? 
Pressure_Std= df['Press_kPa'].std()
print(Pressure_Std)
# Out:
# 0.8440047459486459

# %%
# Q. 8) What is the Variance of 'Relative Humidity' in this data ?
Rel_Hum = df['Rel Hum_%'].var()
print(Rel_Hum)
# Out:
# 286.2485501985015

# %%
df.value_counts(df['Weather Condition'])
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# Q. 9) Find all instances when 'Snow' was recorded. 
Snow_Weather= df[df['Weather Condition']=='Snow']
print(Snow_Weather)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 11    01-01-2012 11:00    -6.2              -9.6         37               35
# 70    03-01-2012 22:00    -4.0              -6.6         62               22
# 73    04-01-2012 01:00     2.3              -3.4         64               35
# 105   05-01-2012 09:00    -1.8              -4.2         73               15
# 112   05-01-2012 16:00     1.7              -0.3         75                6
# ...                ...     ...               ...        ...              ...
# 8573   9/22/2012 13:00    -6.0             -10.2         82               19
# 8650   9/25/2012 18:00    -4.6              -6.6         52                4
# 8671   9/26/2012 15:00    -5.9             -10.5         60               13
# 8713    9/28/2012 1:00    -5.2              -7.8         72               33
# 8734    9/28/2012 8:00     0.7              -1.2         79               30
#
# ...

# %%
# Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.
filtered_data = df[(df['Wind Speed_km/h']>24)&(df['Visibility_km']==25)]
print(filtered_data)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 73    04-01-2012 01:00     2.3              -3.4         64               35
# 126   06-01-2012 06:00    10.0               5.4         77               39
# 158   07-01-2012 14:00     1.9              -2.1         87               26
# 184   08-01-2012 16:00    14.2               9.2         35               44
# ...                ...     ...               ...        ...              ...
# 8707    9/27/2012 5:00    -1.0              -6.0         70               33
# 8714   9/28/2012 10:00     2.6               0.3         72               26
# 8738   9/29/2012 10:00    22.8              12.3         80               28
# 8745   9/29/2012 17:00   -10.3             -12.9         82               28
# 8776   9/30/2012 23:00    19.2              13.2         93               43
#
# ...

# %%
# Q. 11) What is the Mean value of each column against each 'Weather Condition ?
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.loc[df['Weather Condition']=='Clear'].mean()
# Out:
# C:\Users\Ranjith\AppData\Local\Temp\ipykernel_16056\3696272427.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.loc[df['Weather Condition']=='Clear'].mean()
# Temp_C                6.825716
# Dew Point Temp_C      0.089367
# Rel Hum_%            67.127451
# Wind Speed_km/h      10.557315
# Visibility_km        30.153243
# Press_kPa           101.084495
# dtype: float64

# %%
df['Weather Condition'].unique()
# Out:
# array(['Clear', 'Rain', 'Cloudy', 'Mainly Clear', 'Mostly Cloudy', 'Snow',
#        'Fog', 'Rain,Fog', 'Freezing Drizzle', 'Rain Showers', 'Snow,Fog',
#        'Rain,Snow Grains', 'Thunderstorms,Rain Showers,Fog', 'Drizzle',
#        'Rain,Snow', 'Freezing Drizzle,Snow',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Drizzle,Fog', 'Haze',
#        'Thunderstorms,Rain', 'Rain,Haze', 'Freezing Rain,Snow Grains',
#        'Drizzle,Snow', 'Snow,Blowing Snow', 'Freezing Rain',
#        'Snow Showers', 'Snow,Ice Pellets', 'Rain,Ice Pellets',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Rain,Fog',
#        'Drizzle,Snow,Fog', 'Freezing Rain,Fog', 'Snow,Haze',
#        'Thunderstorms,Heavy Rain Showers', 'Moderate Snow',
#        'Freezing Drizzle,Haze', 'Moderate Snow,Blowing Snow',
#        'Rain,Snow,Ice Pellets', 'Rain,Snow,Fog', 'Snow Showers,Fog',
#        'Freezing Drizzle,Fog', 'Freezing Rain,Haze', 'Thunderstorms',
# ...

# %%
# Q. 11) What is the Mean value of each column against each 'Weather Condition ?
Mean_eachcolumn = df.groupby('Weather Condition').mean()
(Mean_eachcolumn)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
# Q. 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ? 
result = df.groupby('Weather Condition').agg([min,max])
result
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather Condition
# Clear                                    01-01-2012 00:00    9/30/2012 7:00
# Cloudy                                   01-01-2012 02:00    9/30/2012 8:00
# Drizzle                                  01-06-2012 08:00   9/15/2012 22:00
# Drizzle,Fog                              01-04-2012 01:00   9/19/2012 15:00
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00    7/24/2012 5:00
# Drizzle,Snow                             05-02-2012 09:00    3/17/2012 1:00
# Drizzle,Snow,Fog                         03-11-2012 20:00   9/21/2012 12:00
# Fog                                      01-01-2012 13:00   9/30/2012 19:00
# Freezing Drizzle                         04-01-2012 03:00    8/21/2012 5:00
# Freezing Drizzle,Fog                      10/15/2012 4:00    7/26/2012 6:00
# ...

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %%
# Q. 13) Show all the Records where Weather Condition is Fog.
Fog_Records = df[df['Weather Condition']=='Fog']
Fog_Records
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13    01-01-2012 13:00     9.5               7.8         40               13
# 53    03-01-2012 05:00    -3.6              -4.3         57                7
# 136   06-01-2012 16:00    14.8              13.5         80               19
# 197   09-01-2012 05:00     2.1               0.7         43               11
# 278   12-01-2012 14:00     1.2               0.6         70               13
# ...                ...     ...               ...        ...              ...
# 8475   9/18/2012 11:00     6.2               5.4         56                7
# 8511   9/19/2012 22:00    15.7              15.4         66                7
# 8518    9/19/2012 8:00    -2.9              -4.5         68                6
# 8537    9/20/2012 3:00    -0.5              -2.1         74                7
# 8771   9/30/2012 19:00    12.8              12.2         91               19
#
# ...

# %%
count = 0
for i in df['Weather Condition']:
    if i == 'Fog':
        count+=1
count
# Out:
# 150

# %%
# Q. 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'. 
result = df[(df['Weather Condition']=='Clear') | (df['Visibility_km']>40)]
result
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 9     01-01-2012 09:00    20.0               3.8         35               17
# 16    01-01-2012 16:00    23.8              17.6         42                9
# 17    01-01-2012 17:00    -6.8              -9.8         42               20
# 18    01-01-2012 18:00     2.3              -2.4         42                6
# ...                ...     ...               ...        ...              ...
# 8774   9/30/2012 21:00    23.0              14.7         92               13
# 8777    9/30/2012 3:00     9.3               5.8         95                9
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
#
# ...

# %%
A_df = df[(df['Weather Condition']=='Clear') & (df['Rel Hum_%']>50)]
(A_df)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 35    02-01-2012 11:00     9.1               6.2         53                6
# 37    02-01-2012 13:00   -12.0             -18.2         54               22
# 40    02-01-2012 16:00    21.5              10.9         54                0
# 50    03-01-2012 02:00    18.9              16.2         56                9
# 51    03-01-2012 03:00    22.2               5.5         57               19
# ...                ...     ...               ...        ...              ...
# 8735    9/28/2012 9:00    14.2              12.9         80                4
# 8743   9/29/2012 15:00    17.7               7.8         81                9
# 8768   9/30/2012 16:00    18.2               8.8         90                4
# 8770   9/30/2012 18:00    24.6              12.6         90               15
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
#
# ...

# %%
'''Q. 15) Find all instances when : 
A. 'Weather is Clear' and 'Relative Humidity is greater than 50' 
or 
B. 'Visibility is above 40'''
result =df[((df['Weather Condition']=='Clear') & (df['Rel Hum_%']>50))|(df['Visibility_km']>40)]
result
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9     01-01-2012 09:00    20.0               3.8         35               17
# 17    01-01-2012 17:00    -6.8              -9.8         42               20
# 18    01-01-2012 18:00     2.3              -2.4         42                6
# 19    01-01-2012 19:00   -12.7             -17.2         43               17
# 23    01-01-2012 23:00    29.5              16.8         45                4
# ...                ...     ...               ...        ...              ...
# 8774   9/30/2012 21:00    23.0              14.7         92               13
# 8777    9/30/2012 3:00     9.3               5.8         95                9
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
#
# ...
